# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Carlos Galvao
#
# Nome: Pedro Hun
#
# Nome: Luiz Gustavo Reis

# %% [markdown]
# Atenção: Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
# %pip install emoji
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import re
import emoji
import functools
import operator
# Out:
# Requirement already satisfied: emoji in c:\programdata\anaconda3\lib\site-packages (1.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\lugus\OneDrive\Documentos\Projeto1-Cdados\cdadosCGLR-1\Projeto1-Cdados

# %% [markdown]
# Carregando a base de dados com os tweets classificados como relevantes e não relevantes:

# %%
filename = 'pringles_1000.xlsx'

# %%
train = pd.read_excel(filename, sheet_name = 'Treinamento')
train.drop('Legenda', axis=1, inplace=True)
train.head(5)
# Out:
#                                          Treinamento  Classificação
# 0       se deixar eu vivo a vida só comendo pringles              1
# 1  senhor tira essa vontade de comer batata pring...              1
# 2  tomando um vinho rosé e comendo pringles #quintou              1
# 3  segui hj alimentação que a nutri passou e cagu...              0
# 4  @pringles_007 @conversasboas vc me dá bolo até...              0

# %%
test = pd.read_excel(filename, sheet_name = 'Teste')
test.drop('Legenda', axis=1, inplace=True)
test.head(5)
# Out:
#                                                Teste  Classificação
# 0  eu jantei dois pacotes de miojo\ncomi um punha...            2.0
# 1               n sei onde dea enfiou minha pringles            0.0
# 2  comprei 2 pringles vou levar anos pra me recup...            2.0
# 3  @bhaktsehgal @alamg33r @devrajin_1 @a_grvp_ @s...            0.0
# 4  @underpantsus eu tbm não esperava, achei que f...            0.0

# %% [markdown]
# ___
# ## Classificador automático de sentimento

# %% [markdown]
# Faça aqui uma descrição do seu produto e o que considerou como relevante ou não relevante na classificação dos tweets.
#
# ESCREVA AQUI...
#
# Irrelevante para tweets sem relacao nenhuma com a qualidade do produto.
# Pouco Relevante para tweets com pouca relacao com a qualidade do produto.
# Relevante para tweets com relacao com a qualidade do produto.
# Muito Relevante para tweets com muita relacao com a qualidade do produto.

# %% [markdown]
# ___
# ### Montando um Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %%
## Limpezas: Minusculo - Emojis(emoji) - Pontuacoes(re) - StopWords; (nltk)

# %%
def pontuacao(text):
    text = text.replace('\n',' ')
    punctuation = '[!-.:?;]'
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, '', text)
    return text_subbed

def minusculo(text):
    text_subbed = text.lower()
    return text_subbed

def emojiseparar(em):
    em_split_emoji = emoji.get_emoji_regexp().split(em)
    em_split_whitespace = [substr.split() for substr in em_split_emoji]
    em_split = functools.reduce(operator.concat, em_split_whitespace)
    text_subbed = ' '.join(em_split)
    return text_subbed

def arroba(text):
    punctuation = r'@\w+'
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, '', text)
    return text_subbed

def limpar(text):
    text = pontuacao(text)
    text = minusculo(text)
#    text = emojiseparar(text)
    text = arroba(text)
    return text

test.Teste = test.Teste.apply(limpar)
train.Treinamento = train.Treinamento.apply(limpar)

# %%
filtra_linhas = train['Classificação'] == 0
irrelevante = train.loc[filtra_linhas, :]
todas_palavras_irrelevante = []
for tweet in irrelevante['Treinamento']:
        lista_i = tweet.split()
        for palavra in lista_i:
            todas_palavras_irrelevante.append(palavra)

serie_todas_palavras_irrelevante = pd.Series(todas_palavras_irrelevante)
tabela_todas_palavras_irrelevante = serie_todas_palavras_irrelevante.value_counts(True)
tabela_todas_palavras_irrelevante.head(10)
# Out:
# pringles    0.054167
# de          0.038636
# e           0.034848
# o           0.019697
# uma         0.019318
# eu          0.017045
# a           0.017045
# que         0.016667
# um          0.014015
# pra         0.010985
# dtype: float64

# %%
filtra_linhas = train['Classificação'] == 1
pouco_relevante = train.loc[filtra_linhas, :]
todas_palavras_pouco_relevante = []
for tweet in pouco_relevante['Treinamento']:
        lista_pr = tweet.split()
        for palavra in lista_pr:
            todas_palavras_pouco_relevante.append(palavra)

serie_todas_palavras_pouco_relevante = pd.Series(todas_palavras_pouco_relevante)
tabela_todas_palavras_pouco_relevante = serie_todas_palavras_pouco_relevante.value_counts(True)
tabela_todas_palavras_pouco_relevante
# Out:
# pringles    0.067170
# e           0.036981
# de          0.033208
# eu          0.023396
# que         0.018868
#               ...
# 0           0.000755
# pela        0.000755
# favorita    0.000755
# hj          0.000755
# pobre       0.000755
# Length: 575, dtype: float64

# %%
filtra_linhas = train['Classificação'] == 2
relevante = train.loc[filtra_linhas, :]
todas_palavras_relevante = []
for tweet in relevante['Treinamento']:
        lista_pr = tweet.split()
        for palavra in lista_pr:
            todas_palavras_relevante.append(palavra)

serie_todas_palavras_relevante = pd.Series(todas_palavras_relevante)
tabela_todas_palavras_relevante = serie_todas_palavras_relevante.value_counts(True)
tabela_todas_palavras_relevante
# Out:
# pringles    0.065974
# de          0.042150
# e           0.035431
# eu          0.018326
# a           0.017715
#               ...
# fico        0.000611
# bebendo     0.000611
# agr         0.000611
# hj          0.000611
# simples     0.000611
# Length: 675, dtype: float64

# %%
filtra_linhas = train['Classificação'] == 3
muito_relevante = train.loc[filtra_linhas, :]
todas_palavras_muito_relevante = []
for tweet in muito_relevante['Treinamento']:
        lista_pr = tweet.split()
        for palavra in lista_pr:
            todas_palavras_muito_relevante.append(palavra)

serie_todas_palavras_muito_relevante = pd.Series(todas_palavras_muito_relevante)
tabela_todas_palavras_muito_relevante = serie_todas_palavras_muito_relevante.value_counts(True)
tabela_todas_palavras_muito_relevante
# Out:
# pringles    0.088889
# de          0.054762
# é           0.028571
# e           0.026984
# que         0.021429
#               ...
# acaba       0.000794
# confiem     0.000794
# tinha       0.000794
# amar        0.000794
# qria        0.000794
# Length: 499, dtype: float64

# %%
todas_palavras = []
for tweet in train['Treinamento']:
    lista_p = tweet.split()
    for palavra in lista_p:
        todas_palavras.append(palavra)
        

serie_todas_palavras = pd.Series(todas_palavras)
tabela_todas_palavras = serie_todas_palavras.value_counts(True)
tabela_todas_palavras
# Out:
# pringles         0.065870
# de               0.041387
# e                0.033955
# o                0.017633
# eu               0.017633
#                    ...
# mimar            0.000146
# cinemas          0.000146
# manga/laranja    0.000146
# 29               0.000146
# segurando        0.000146
# Length: 1902, dtype: float64

# %%
prob_0 = len(todas_palavras_irrelevante)/len(todas_palavras)
prob_0
# Out:
# 0.3847274846983387

# %%
prob_1 = len(todas_palavras_pouco_relevante)/len(todas_palavras)
prob_1
# Out:
# 0.19309239288837074

# %%
prob_2 =  len(todas_palavras_relevante)/len(todas_palavras)
prob_2
# Out:
# 0.23856018653453803

# %%
prob_3 =  len(todas_palavras_muito_relevante)/len(todas_palavras)
prob_3
# Out:
# 0.18361993587875255

# %%
a = prob_0 + prob_1 + prob_2 + prob_3
print(a)
# Out:
# 1.0

# %%
lista_todas_as_listas = [todas_palavras_irrelevante, todas_palavras_pouco_relevante, todas_palavras_relevante, todas_palavras_muito_relevante]
lista_todas_as_tabelas = [tabela_todas_palavras_irrelevante, tabela_todas_palavras_pouco_relevante, tabela_todas_palavras_relevante, tabela_todas_palavras_muito_relevante]

# %%
def prob(tweet,lista_todas_as_tabelas, lista_todas_as_listas):
    probability = 1
    lista_funcao = []
    for tabela_relativa in lista_todas_as_tabelas:
        contador_1 = 0
        multiplicador = 1
        for lista in lista_todas_as_listas:
            for palavra in tweet.split():
                if contador_1 >= len(tweet.split()) :
                    break
                if palavra in tabela_relativa:
                    probability = (1 + tabela_relativa[palavra])
                    contador_1 +=1
                else:
                    probabilidade = 1
                    contador_1 +=1
                multiplicador *= probability
        lista_funcao.append(multiplicador)
    if lista_funcao.index(max(lista_funcao)) == 0:
        return 'irrelevante'
    elif lista_funcao.index(max(lista_funcao)) == 1:
        return 'pouco relevante'
    elif lista_funcao.index(max(lista_funcao)) == 2:
        return 'relevante'
    elif lista_funcao.index(max(lista_funcao)) == 3:
        return 'muito relevante'
    
print(prob('a',lista_todas_as_tabelas,lista_todas_as_listas))
# Out:
# relevante

# %%
lista_classificador= []
for a in train['Treinamento']:
    lista_classificador.append(prob(a,lista_todas_as_tabelas,lista_todas_as_listas))
train['pc classifica'] = lista_classificador
train.head(50)
# Out:
#                                           Treinamento  Classificação  \
# 0        se deixar eu vivo a vida só comendo pringles              1
# 1   senhor tira essa vontade de comer batata pring...              1
# 2    tomando um vinho rosé e comendo pringles quintou              1
# 3   segui hj alimentação que a nutri passou e cagu...              0
# 4     vc me dá bolo até em filme q é por chamada i...              0
# 5   eu digo svv pq viver em uma sociedade em que u...              2
# 6                                    vai me processar              0
# 7    euro tá 612   se for comprar 10 euros em prin...              2
# 8   comi uma pringles mega logo depois de jantar v...              1
# 9   pedi bis pringles e bombom paguei só 13 reais ...              0
# 10  mds o pringles de cheese burger parece que eu ...              3
# 11  estourei a boca de tanto comer pringles sal e ...              2
# 12  meia embalagem de pringles conta como jantar c...              2
# 13           pela pringles eu bebo o mar de canudinho              0
# 14  comprei pringles  e finni para ana júlia vai f...              1
# 15  acabei de comprar a nova pringles xburger 🍟🍔 e...              0
# 16  poxa eu ofereci um pouco de pringles para meu ...              0
# 17        comprei pringles finalmente matei meu verme              0
# 18  tenham amigos que te tragam fini e pringles ht...              1
# 19  comprei 2 potes de pringles e deixei de pagar ...              2
# 20  hoje vou me mimar com um energético e um pring...              2
# 21          n sei explica como amo pringles de cebola              3
# 22               acho bom mesmo https//tco/avuzipu5kw              0
# 23  vou continuar com oq eu fazia na outra conta p...              0
# 24                                ¿pringles o doritos              0
# 25        saindo do supermercado com mamão e pringles              0
# 26    comendo pringles esperando as esfirras chegarem              0
# 27              pringles em promoção só me lembra ele              0
# 28     simmmmmm comprei 2 pringles esses dias e pa...              2
# 29  seunghun o o que tá rolando no corredor do pri...              0
# 30  pringles diminuiu o sal e agora gastei 12 cont...              2
# 31              kkkkk vo preferir a pringles obrigada              0
# 32  comprei pringles e tô me sentindo apenas a mul...              2
# 33                     meu café da manhã pringles 😍😍😍              2
# 34             me dá nem o pringles q eu peço véi vtf              0
# 35            pringles de cheddar e bacon é muito bom              3
# 36  uma batata pringles tá 10 conto o assalto meu pai              3
# 37  a nova pringles sabor cheese burger é tudo ps ...              3
# 38           espionando é vcs combinarem role sem mim              0
# 39   roubou a minha pringles e depois a professora...              0
# 40  pringles de churrasco é bom e o de cheddar só ...              2
# 41   eu fui no mercado hoje ia comprar pringles ma...              2
# 42  jantei tequila e doritos tô almoçando pringles...              0
# 43  particularmente falando os melhores acompanham...              2
# 44  ontem meu café da manhã foi uma cumbuca de fru...              0
# 45   aqui em casa elástico de cabelo tampa de pia ...              0
# 46  ㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤ𝐆osta de batata pringles mo ...              3
# 47  chegou a notificação que minha avó entrou no t...              0
# 48    kkkkkk débora ele é filho de um trisal o gar...              0
# 49  maluco quem em sã consciência faz purê de bata...              0
#
#       pc classifica
# 0   muito relevante
# 1   muito relevante
# 2   muito relevante
# 3   muito relevante
# 4         relevante
# 5       irrelevante
# 6       irrelevante
# 7   pouco relevante
# 8   muito relevante
# 9   muito relevante
# 10      irrelevante
# 11  muito relevante
# 12  muito relevante
# 13  muito relevante
# 14  muito relevante
# 15        relevante
# 16  muito relevante
# 17  muito relevante
# 18  muito relevante
# 19  muito relevante
# 20  pouco relevante
# 21  muito relevante
# 22  muito relevante
# 23        relevante
# 24  pouco relevante
# 25  muito relevante
# 26  muito relevante
# 27  muito relevante
# 28  muito relevante
# 29  muito relevante
# 30  muito relevante
# 31  muito relevante
# 32  pouco relevante
# 33  muito relevante
# 34  pouco relevante
# 35  pouco relevante
# 36  muito relevante
# 37  muito relevante
# 38        relevante
# 39        relevante
# 40  muito relevante
# 41  muito relevante
# 42  pouco relevante
# 43  pouco relevante
# 44  muito relevante
# 45  muito relevante
# 46        relevante
# 47  muito relevante
# 48  muito relevante
# 49        relevante

# %% [markdown]
# ___
# ### Verificando a performance do Classificador
#
# Agora você deve testar o seu classificador com a base de Testes.

# %%
lista_classificador= []
for a in test['Teste']:
    lista_classificador.append(prob(a,lista_todas_as_tabelas,lista_todas_as_listas))
test['pc classifica'] = lista_classificador
test.head(50)
# Out:
#                                                 Teste  Classificação  \
# 0   eu jantei dois pacotes de miojo comi um punhad...            2.0
# 1                n sei onde dea enfiou minha pringles            0.0
# 2   comprei 2 pringles vou levar anos pra me recup...            2.0
# 3                         🤣🤣🤣🤣🤣🤣🤣🤣  paisa paisa 🤣🤣🤣🤣🤣            0.0
# 4    eu tbm não esperava achei que fosse ser do xb...            0.0
# 5   abri o fini e coloquei uma batatinha pringles ...            3.0
# 6     quem dera fosse só o pringles q está diminuindo            0.0
# 7   um cara pediu pra eu comprar um salgadinho pra...            2.0
# 8   comi 1 pringles de cheeseburguer q tem um puta...            3.0
# 9                                   o melhor pringles            3.0
# 10  e meu irmão que comprou 2 pringles pra mim pq ...            3.0
# 11                        eu essa semana com pringles            0.0
# 12   meu jantar de aniversário é espumante e pringles            3.0
# 13   pringles é bomlembro até hj dos dia q eu comi...            3.0
# 14  acho que pringles creme e cebola é meu salgadi...            3.0
# 15   o pringles com cinzas de baseado foi foda kkk...            0.0
# 16   sou muito viciada em  chega a me dar abstinência            3.0
# 17  encerra plmdds eu to com fome almocei uma prin...            2.0
# 18                                             seu cu            0.0
# 19  indo no mercado so p comprar pringles e chocol...            3.0
# 20  o diâmetro de uma lata de pringles é muito peq...            3.0
# 21   você não vai usar uma lata de pringles em maq...            0.0
# 22   o pringles é uma delícia e a rufles normal nã...            2.0
# 23  agora eu só lembro da aline quando tô comendo ...            0.0
# 24                                pringles é superior            1.0
# 25   eu to fazendo com pringles https//tco/o7ipkns0q8            0.0
# 26  não gosto de cebola mas amo pringles creme e c...            3.0
# 27  meu irmão acabou de derrubar um pote de pringl...            0.0
# 28   aaah eu sou formiguinha ele sempre faz mais c...            1.0
# 29  eu preciso desenvolver a coragem de desagradar...            0.0
# 30                     pringles de queijo tudo de bom            3.0
# 31       ¿dormir temprano  no ubico esa serie br0 😵‍💫            0.0
# 32  melhor coisa q fiz hj foi ter comprado essa ba...            3.0
# 33  eu dei 12 reais numa pringles podem assinar mi...            2.0
# 34  e se eu pegasse as latas de pringles que tá aq...            0.0
# 35   carai o gordito carregando bata pringles era ...            0.0
# 36   papo reto eu achei q era pringles mass tava t...            1.0
# 37                       ja foi https//tco/mkqqkvbgsz            0.0
# 38  uma das pequenas vitórias da vida adulta é pod...            2.0
# 39  pagar 8 reais no pote de pringles é a razão da...            3.0
# 40  uma pringles uma ruffles média e 100g de bisco...            2.0
# 41  até cozinhei feijão mas jantar batata pringles...            3.0
# 42   gastando meu dinheiro tdo comprando pringles lt3            2.0
# 43                não consigo parar de comer pringles            3.0
# 44  só deus pode me julgar  deus me vendo jantar p...            3.0
# 45  eu n consigo me desfazer de uma lata de pringl...            2.0
# 46    se o flamengo tiver certo agora eu sou uma c...            0.0
# 47  a minha love language é ver pride and prejudic...            2.0
# 48   eu descobri que sai mais em conta comprar pri...            3.0
# 49                                               aqui            0.0
#
#       pc classifica
# 0   muito relevante
# 1   muito relevante
# 2   muito relevante
# 3       irrelevante
# 4   muito relevante
# 5   muito relevante
# 6   muito relevante
# 7   muito relevante
# 8   muito relevante
# 9   muito relevante
# 10  pouco relevante
# 11  muito relevante
# 12  muito relevante
# 13  muito relevante
# 14  muito relevante
# 15  muito relevante
# 16        relevante
# 17  pouco relevante
# 18  pouco relevante
# 19  muito relevante
# 20  muito relevante
# 21  muito relevante
# 22  muito relevante
# 23  pouco relevante
# 24  muito relevante
# 25  muito relevante
# 26  muito relevante
# 27  pouco relevante
# 28  muito relevante
# 29  muito relevante
# 30  muito relevante
# 31  pouco relevante
# 32  muito relevante
# 33  muito relevante
# 34  muito relevante
# 35        relevante
# 36  muito relevante
# 37      irrelevante
# 38  muito relevante
# 39  muito relevante
# 40  muito relevante
# 41  muito relevante
# 42  muito relevante
# 43  muito relevante
# 44  muito relevante
# 45  muito relevante
# 46  muito relevante
# 47        relevante
# 48  muito relevante
# 49        relevante

# %%
def converteemnumero(nivel):
    if nivel == 'irrelevante':
        return 0
    elif nivel == 'pouco relevante':
        return 1
    elif nivel == 'relevante':
        return 2
    else:
        return 3
    
valorestestados = []
for x in test['Classificação']:
    valorestestados.append(x)

valorescalculados = []
for y in test['pc classifica']:
    valor = converteemnumero(y)
    valorescalculados.append(valor)

acertos = 0
total = 0
i=0
while i <= len(valorescalculados)-1:
    if valorestestados[i] == valorescalculados[i]:
        acertos+=1
    total+=1
    i+=1

qualidade = (acertos/total)*100

print(" acertou em {}% das vezes".format(qualidade))
# Out:
#  acertou em 27.400000000000002% das vezes

# %%
fal_positivos = 0
verd_positivos = 0
i = 0
total = 0

while i < len(valorescalculados):
    if valorescalculados[i] == 2 or valorescalculados[i] == 3:
        if valorestestados[i] == 2 or valorestestados[i] == 3: 
            verd_positivos +=1
        else: 
            fal_positivos += 1
    i+=1
    total+=1

fal_positivos *= 100
verd_positivos*= 100

print('Falsos positivos: {}%'.format(fal_positivos/total))
print('Verdadeiros positivos: {}%'.format(verd_positivos/total))

fal_negativos = 0
verd_negativos = 0
i = 0
total = 0

while i < len(valorescalculados):
    if valorescalculados[i] == 2 or valorescalculados[i] == 1: 
        if valorestestados[i] == 2 or valorestestados[i] == 1: 
            verd_negativos +=1
        else:
            fal_negativos += 1
    i+=1
    total+=1


fal_negativos *= 100
verd_negativos *= 100
print('Falsos negativos: {}%'.format(fal_negativos/total))
print('Verdadeiros negativos: {}%'.format(verd_negativos/total))
# Out:
# Falsos positivos: 34.4%
# Verdadeiros positivos: 44.4%
# Falsos negativos: 18.4%
# Verdadeiros negativos: 10.2%

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ___
# ### Qualidade do Classificador a partir de novas separações dos tweets entre Treinamento e Teste
#
# Caso for fazer esse item do Projeto

# %% [markdown]
# ___
# ## Aperfeiçoamento:
#
# Trabalhos que conseguirem pelo menos conceito B vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * IMPLEMENTOU outras limpezas e transformações que não afetem a qualidade da informação contida nos tweets. Ex: stemming, lemmatization, stopwords
# * CORRIGIU separação de espaços entre palavras e emojis ou entre emojis e emojis
# * CRIOU categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante. Pelo menos quatro categorias, com adição de mais tweets na base, conforme enunciado. (OBRIGATÓRIO PARA TRIOS, sem contar como item avançado)
# * EXPLICOU porquê não pode usar o próprio classificador para gerar mais amostras de treinamento
# * PROPÔS diferentes cenários para Naïve Bayes fora do contexto do projeto
# * SUGERIU e EXPLICOU melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * FEZ o item 6. Qualidade do Classificador a partir de novas separações dos tweets entre Treinamento e Teste descrito no enunciado do projeto (OBRIGATÓRIO para conceitos A ou A+)

# %% [markdown]
# ___
# ## Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
